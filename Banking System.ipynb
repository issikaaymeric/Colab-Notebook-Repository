# %%
class BankAccount:
    def __init__(self, account_name, initial_balance=0):
        self.account_name = account_name
        self.balance = initial_balance

    def show_balance(self):
        return f"Welcome {self.account_name}. Your account balance is: ${self.balance:.2f}"

    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
            return f"${amount:.2f} deposited successfully. {self.show_balance()}"
        else:
            return "Invalid deposit amount. Please enter a positive value."

    def withdraw(self, amount):
        if amount > 0 and amount <= self.balance:
            self.balance -= amount
            return f"${amount:.2f} withdrawn successfully. {self.show_balance()}"
        else:
            return "Invalid withdrawal amount or insufficient balance."

def main():
    print("Welcome to the Bank Account Program!")
    account_name = input("Please enter your name: ")
    account = BankAccount(account_name)
    print(f"Account created for {account_name}. Initial balance is $0.00.")

    while True:
        print("\n--- Menu ---")
        print("1. Check Balance")
        print("2. Deposit Money")
        print("3. Withdraw Money")
        print("4. Exit")
        user_choice = input("Choose an option (1-4): ")

        if user_choice == "1":
            print(account.show_balance())
        elif user_choice == "2":
            try:
                amount = float(input("Enter the amount to deposit: "))
                print(account.deposit(amount))
            except ValueError:
                print("Invalid input. Please enter a valid number.")
        elif user_choice == "3":
            try:
                amount = float(input("Enter the amount to withdraw: "))
                print(account.withdraw(amount))
            except ValueError:
                print("Invalid input. Please enter a valid number.")
        elif user_choice == "4":
            print("Thank you for using the Bank Account Program. Goodbye!")
            break
        else:
            print("Invalid input. Please choose a valid option.")

if __name__ == "__main__":
    main()
# Out:
# Welcome to the Bank Account Program!
# Account created for Kouamé. Initial balance is $0.00.
#
# --- Menu ---
# 1. Check Balance
# 2. Deposit Money
# 3. Withdraw Money
# 4. Exit
# Welcome Kouamé. Your account balance is: $0.00
#
# --- Menu ---
# 1. Check Balance
# 2. Deposit Money
# 3. Withdraw Money
# 4. Exit
# $1000.00 deposited successfully. Welcome Kouamé. Your account balance is: $1000.00
#
# --- Menu ---
# 1. Check Balance
# 2. Deposit Money
# 3. Withdraw Money
# 4. Exit
